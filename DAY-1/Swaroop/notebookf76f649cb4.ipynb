# %% [markdown]
# ## Name:- Swaroop

# %%
import pandas as pd

# %%
data = {'Name':['John', 'Anna', 'Peter'],
       'Age': [35, 28, 42],
        'City':['NY', 'London', 'Delhi']
       }
print(data)
# Out:
# {'Name': ['John', 'Anna', 'Peter'], 'Age': [35, 28, 42], 'City': ['NY', 'London', 'Delhi']}

# %%
df = pd.DataFrame(data)

print(df.head(2))
# Out:
#    Name  Age    City
# 0  John   35      NY
# 1  Anna   28  London

# %%
# To show only a set of columns use the following
df[['Name', 'Age']]
# Out:
#     Name  Age
# 0   John   35
# 1   Anna   28
# 2  Peter   42

# %%
# Add another column
df['Occupation'] = ['Engineer', 'Artist', 'Doctor']

# %%
# Filter the data frame using conditions
filtered_df = df[df['Age'] > 30]
print(filtered_df)

# Sort the Dataframe
s_df = df.sort_values('Age')
print(s_df)
# Out:
#     Name  Age   City Occupation
# 0   John   35     NY   Engineer
# 2  Peter   42  Delhi     Doctor
#     Name  Age    City Occupation
# 1   Anna   28  London     Artist
# 0   John   35      NY   Engineer
# 2  Peter   42   Delhi     Doctor

# %% [markdown]
# ## Numpy

# %%
import numpy as np

# %%
# Create a numpy array
np_array1 = np.array([1, 2, 3])
np_array2 = np.array([2, 3, 4])

print(np_array1.dot(np_array2))
print(np_array1 * np_array2)
print(np_array1 + np_array2)
print(np_array1 - np_array2)
# Out:
# 20
# [ 2  6 12]
# [3 5 7]
# [-1 -1 -1]

# %% [markdown]
# ## Matplotlib

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
# print(y1*y1 + y2*y2)

# %%
plt.figure(figsize=(4,3))
plt.plot(x, y1, label="Sin(x)")
plt.plot(x, y2, label="Cos(x)", linestyle = '--')
plt.title('Sine Function')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()
plt.show()
plt.imshow(np.reshape(x, (x.size, 1)))

# %% [markdown]
# ## Capstone Project Solution

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/kaggle/input/cars-data/used_cars_data1.csv")
print("Shape of the dataset", data.shape)
# Out:
# Shape of the dataset (7253, 14)

# %%
data.nunique()
# Out:
# S.No.                7253
# Name                 2041
# Location               11
# Year                   23
# Kilometers_Driven    3660
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               450
# Engine                150
# Power                 386
# Seats                   9
# New_Price             625
# Price                1373
# dtype: int64

# %%
data.isnull().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# S.No.                 0.000000
# Name                  0.000000
# Location              0.000000
# Year                  0.000000
# Kilometers_Driven     0.000000
# Fuel_Type             0.000000
# Transmission          0.000000
# Owner_Type            0.000000
# Mileage               0.027575
# Engine                0.634220
# Power                 0.634220
# Seats                 0.730732
# New_Price            86.129877
# Price                17.013650
# dtype: float64

# %%
data["Model"] = data.Name.str.split().str.get(1) + data.Name.str.split().str.get(2)
data['Brand'] = data.Name.str.split().str.get(0)

# %%
print(data.Brand.unique())
# Out:
# ['Maruti' 'Hyundai' 'Honda' 'Audi' 'Nissan' 'Toyota' 'Volkswagen' 'Tata'
#  'Land' 'Mitsubishi' 'Renault' 'Mercedes-Benz' 'BMW' 'Mahindra' 'Ford'
#  'Porsche' 'Datsun' 'Jaguar' 'Volvo' 'Chevrolet' 'Skoda' 'Mini' 'Fiat'
#  'Jeep' 'Smart' 'Ambassador' 'Isuzu' 'ISUZU' 'Force' 'Bentley'
#  'Lamborghini' 'Hindustan' 'OpelCorsa']

# %%
data=data.drop(['S.No.'], axis=1)

# %%
from datetime import date
date.today().year
data['Car_Age'] = date.today().year - data['Year']
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price      Model    Brand  Car_Age
# 0        NaN   1.75     WagonR   Maruti       13
# 1        NaN  12.50   Creta1.6  Hyundai        8
# 2  8.61 Lakh   4.50      JazzV    Honda       12
# 3        NaN   6.00  ErtigaVDI   Maruti       11
# 4        NaN  17.74      A4New     Audi       10

# %%
data['Brand'] = data.Name.str.split().str.get(0)
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price      Model    Brand  Car_Age
# 0        NaN   1.75     WagonR   Maruti       13
# 1        NaN  12.50   Creta1.6  Hyundai        8
# 2  8.61 Lakh   4.50      JazzV    Honda       12
# 3        NaN   6.00  ErtigaVDI   Maruti       11
# 4        NaN  17.74      A4New     Audi       10

# %%
data['Model'] = data.Name.str.split().str.get(1)+data.Name.str.split().str.get(2)
data[['Name','Brand','Model']]
print(data.Brand.unique())
# Out:
# ['Maruti' 'Hyundai' 'Honda' 'Audi' 'Nissan' 'Toyota' 'Volkswagen' 'Tata'
#  'Land' 'Mitsubishi' 'Renault' 'Mercedes-Benz' 'BMW' 'Mahindra' 'Ford'
#  'Porsche' 'Datsun' 'Jaguar' 'Volvo' 'Chevrolet' 'Skoda' 'Mini' 'Fiat'
#  'Jeep' 'Smart' 'Ambassador' 'Isuzu' 'ISUZU' 'Force' 'Bentley'
#  'Lamborghini' 'Hindustan' 'OpelCorsa']

# %%
searchfor = ['Isuzu','ISUZU','Land','Mini']
data[data.Brand.str.contains('|'.join(searchfor))].head()
# Out:
#                                     Name    Location  Year  Kilometers_Driven  \
# 13      Land Rover Range Rover 2.2L Pure       Delhi  2014              72000
# 14        Land Rover Freelander 2 TD4 SE        Pune  2012              85000
# 176             Mini Countryman Cooper D      Jaipur  2017               8525
# 191  Land Rover Range Rover 2.2L Dynamic  Coimbatore  2018              36091
# 228            Mini Cooper Convertible S       Kochi  2017              26327
#
#     Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 13     Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 14     Diesel    Automatic     Second    0.0 kmpl  2179 CC     115 bhp    5.0
# 176    Diesel    Automatic     Second   16.6 kmpl  1998 CC     112 bhp    5.0
# 191    Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 228    Petrol    Automatic      First  16.82 kmpl  1998 CC  189.08 bhp    4.0
#
#       New_Price  Price              Model Brand  Car_Age
# 13          NaN  27.00         RoverRange  Land        9
# 14          NaN  17.50    RoverFreelander  Land       11
# 176         NaN  23.00   CountrymanCooper  Mini        6
# 191         NaN  55.76         RoverRange  Land        5
# 228  44.28 Lakh  35.67  CooperConvertible  Mini        6

# %%
data["Brand"].replace({"ISUZU":"Isuzu", "Mini":"Mini Cooper", "Land": "Land Rover"}, inplace=True)
searchfor = ['Isuzu','ISUZU','Land','Mini']
data[data.Brand.str.contains('|'.join(searchfor))].head()
# Out:
#                                     Name    Location  Year  Kilometers_Driven  \
# 13      Land Rover Range Rover 2.2L Pure       Delhi  2014              72000
# 14        Land Rover Freelander 2 TD4 SE        Pune  2012              85000
# 176             Mini Countryman Cooper D      Jaipur  2017               8525
# 191  Land Rover Range Rover 2.2L Dynamic  Coimbatore  2018              36091
# 228            Mini Cooper Convertible S       Kochi  2017              26327
#
#     Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 13     Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 14     Diesel    Automatic     Second    0.0 kmpl  2179 CC     115 bhp    5.0
# 176    Diesel    Automatic     Second   16.6 kmpl  1998 CC     112 bhp    5.0
# 191    Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 228    Petrol    Automatic      First  16.82 kmpl  1998 CC  189.08 bhp    4.0
#
#       New_Price  Price              Model        Brand  Car_Age
# 13          NaN  27.00         RoverRange   Land Rover        9
# 14          NaN  17.50    RoverFreelander   Land Rover       11
# 176         NaN  23.00   CountrymanCooper  Mini Cooper        6
# 191         NaN  55.76         RoverRange   Land Rover        5
# 228  44.28 Lakh  35.67  CooperConvertible  Mini Cooper        6

# %%
data.describe(include='all').T
# Out:
#                     count unique                     top  freq          mean  \
# Name                 7253   2041  Mahindra XUV500 W8 2WD    55           NaN
# Location             7253     11                  Mumbai   949           NaN
# Year               7253.0    NaN                     NaN   NaN   2013.365366
# Kilometers_Driven  7253.0    NaN                     NaN   NaN  58699.063146
# Fuel_Type            7253      5                  Diesel  3852           NaN
# Transmission         7253      2                  Manual  5204           NaN
# Owner_Type           7253      4                   First  5952           NaN
# Mileage              7251    450               17.0 kmpl   207           NaN
# Engine               7207    150                 1197 CC   732           NaN
# Power                7207    386                  74 bhp   280           NaN
# Seats              7200.0    NaN                     NaN   NaN      5.279722
# New_Price            1006    625              63.71 Lakh     6           NaN
# Price              6019.0    NaN                     NaN   NaN      9.479468
# Model                7252    726              SwiftDzire   189           NaN
# Brand                7253     32                  Maruti  1444           NaN
# Car_Age            7253.0    NaN                     NaN   NaN      9.634634
#
#                             std     min      25%      50%      75%        max
# Name                        NaN     NaN      NaN      NaN      NaN        NaN
# Location                    NaN     NaN      NaN      NaN      NaN        NaN
# Year                   3.254421  1996.0   2011.0   2014.0   2016.0     2019.0
# Kilometers_Driven  84427.720583   171.0  34000.0  53416.0  73000.0  6500000.0
# Fuel_Type                   NaN     NaN      NaN      NaN      NaN        NaN
# Transmission                NaN     NaN      NaN      NaN      NaN        NaN
# Owner_Type                  NaN     NaN      NaN      NaN      NaN        NaN
# Mileage                     NaN     NaN      NaN      NaN      NaN        NaN
# Engine                      NaN     NaN      NaN      NaN      NaN        NaN
# Power                       NaN     NaN      NaN      NaN      NaN        NaN
# Seats                   0.81166     0.0      5.0      5.0      5.0       10.0
# New_Price                   NaN     NaN      NaN      NaN      NaN        NaN
# Price                 11.187917    0.44      3.5     5.64     9.95      160.0
# Model                       NaN     NaN      NaN      NaN      NaN        NaN
# Brand                       NaN     NaN      NaN      NaN      NaN        NaN
# Car_Age                3.254421     4.0      7.0      9.0     12.0       27.0

# %%
cat_cols = data.select_dtypes(include= ['object']).columns
print(cat_cols)
# Out:
# Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type',
#        'Mileage', 'Engine', 'Power', 'New_Price', 'Model', 'Brand'],
#       dtype='object')

# %%
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print(num_cols)
# Out:
# ['Year', 'Kilometers_Driven', 'Seats', 'Price', 'Car_Age']

# %%
x = np.linspace(0, 2 * np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

fig, axes = plt.subplots(2, 1, figsize=(6, 4))

axes[0].plot(x, y1, label='sin(x)', color='b', linestyle='--')
axes[0].set_title('Sine Function')
axes[0].legend()

axes[1].plot(x, y2, label='cos(x)', color='r', linestyle='-')
axes[1].set_title('Cosine Function')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
for col in num_cols:
    print(col)
    print('Skew:', round(data[col].skew(),2))    
    plt.figure(figsize=(15,4))
    plt.subplot(1,2,1)
    data[col].hist(grid=False)
    plt.ylabel('count')    
    plt.subplot(1,2,2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# Year
# Skew: -0.84
# Kilometers_Driven
# Skew: 61.58
# Seats
# Skew: 1.9
# Price
# Skew: 3.34
# Car_Age
# Skew: 0.84

# %%
fig, axes = plt.subplots(3, 2, figsize = (18, 18))
fig.suptitle('Bar plot for all categorical variables in the dataset')
sns.countplot(ax = axes[0, 0], x = 'Fuel_Type', data = data, color = 'blue', 
              order = data['Fuel_Type'].value_counts().index);
sns.countplot(ax = axes[0, 1], x = 'Transmission', data = data, color = 'blue', 
              order = data['Transmission'].value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'Owner_Type', data = data, color = 'blue', 
              order = data['Owner_Type'].value_counts().index);
sns.countplot(ax = axes[1, 1], x = 'Location', data = data, color = 'blue', 
              order = data['Location'].value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'Brand', data = data, color = 'blue', 
              order = data['Brand'].head(20).value_counts().index);
sns.countplot(ax = axes[2, 1], x = 'Model', data = data, color = 'blue', 
              order = data['Model'].head(20).value_counts().index);
axes[1][1].tick_params(labelrotation=45);
axes[2][0].tick_params(labelrotation=90);
axes[2][1].tick_params(labelrotation=90);

# %%
dt= {'A': [1,2,3,4,5],
     'B': [2,4,6,8,10],
     'C': [3,6,9,12,15],
     'D': [20,16,12,8,4]}

df= pd.DataFrame(dt)

# %%
sns.pairplot(df, diag_kind='kde')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(13,17))
sns.pairplot(data)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig, axarr = plt.subplots(2, 2, figsize=(10, 12))
data.groupby('Location')['Price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][0], fontsize=12)
axarr[0][0].set_title("Location Vs Price", fontsize=18)
data.groupby('Transmission')['Price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][1], fontsize=12)
axarr[0][1].set_title("Transmission Vs Price", fontsize=18)
data.groupby('Fuel_Type')['Price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][0], fontsize=12)
axarr[1][0].set_title("Fuel_Type Vs Price", fontsize=18)
data.groupby('Owner_Type')['Price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][1], fontsize=12)
axarr[1][1].set_title("Owner_Type Vs Price", fontsize=18)

plt.subplots_adjust(hspace=1.0)
plt.subplots_adjust(wspace=.5)
sns.despine()

# %%
dt = np.random.rand(10, 10)
print(dt)
sns.heatmap(dt, annot=True, cmap='YlGnBu')
plt.show()
# Out:
# [[0.51488859 0.88059892 0.62403213 0.89921783 0.93469428 0.55096657
#   0.19260466 0.30676858 0.70628804 0.8097386 ]
#  [0.59121195 0.07608453 0.21773342 0.32619005 0.98522838 0.21104683
#   0.97391245 0.74439644 0.90487123 0.8281153 ]
#  [0.40501153 0.93698967 0.95839027 0.11597547 0.46705287 0.23174239
#   0.77612944 0.40736043 0.90145455 0.71537977]
#  [0.62979898 0.13590767 0.28457132 0.01137792 0.51661504 0.8047568
#   0.14943293 0.59985136 0.84820695 0.15638738]
#  [0.58345017 0.71992972 0.51956131 0.02117707 0.56105537 0.0607908
#   0.03521967 0.78248159 0.43104329 0.95636364]
#  [0.07014948 0.9474001  0.29917312 0.24864745 0.57806241 0.7730648
#   0.46418418 0.68346492 0.95557844 0.88826087]
#  [0.30048677 0.57670645 0.76656697 0.76946398 0.01176477 0.5993956
#   0.73680637 0.51785569 0.62678949 0.788094  ]
#  [0.28695775 0.0245188  0.11016714 0.78442635 0.3403297  0.44091795
#   0.49634441 0.14318885 0.51799919 0.74351158]
#  [0.96743073 0.4970119  0.55755809 0.99958291 0.31063448 0.52200571
#   0.20278147 0.73329544 0.87100793 0.34383668]
#  [0.09465681 0.68001346 0.73219432 0.58972569 0.03163037 0.01867281
#   0.76129399 0.744616   0.64029353 0.40168497]]

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price      Model    Brand  Car_Age
# 0        NaN   1.75     WagonR   Maruti       13
# 1        NaN  12.50   Creta1.6  Hyundai        8
# 2  8.61 Lakh   4.50      JazzV    Honda       12
# 3        NaN   6.00  ErtigaVDI   Maruti       11
# 4        NaN  17.74      A4New     Audi       10

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(data[['Kilometers_Driven','Price']].corr(), annot = True, vmin = -1, vmax = 1)
plt.show()

# %%
data.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# Model                   1
# Brand                   0
# Car_Age                 0
# dtype: int64

# %%
data.loc[data["Mileage"]==0.0,'Mileage']=np.nan
data.Mileage.isnull().sum()
# Out:
# 2

# %%
data.Seats.isnull().sum()
data['Seats'].fillna(value=np.nan,inplace=True)

data.groupby(['Model','Brand'])['Seats']

# data['Seats']=data.groupby(['Model','Brand'])['Seats'].apply(lambda x:x.fillna(x.median()))
# data['Engine']=data.groupby(['Brand','Model'])['Engine'].apply(lambda x:x.fillna(x.median()))
# data['Power']=data.groupby(['Brand','Model'])['Power'].apply(lambda x:x.fillna(x.median()))
# Out:
# <pandas.core.groupby.generic.SeriesGroupBy object at 0x7af54281f310>

# %%
data.isnull().sum()
