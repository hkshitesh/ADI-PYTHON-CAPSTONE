# %% [markdown]
# **Name: Sagar Walishetti**

# %%
import pandas as pd

# %%
data = {'Name': ['John', 'Anna', 'peter'],
       'Age': [35,28,42],
        'City': ['NY','London','Delhi']
       }

# %%
print(data)
# Out:
# {'Name': ['John', 'Anna', 'peter'], 'Age': [35, 28, 42], 'City': ['NY', 'London', 'Delhi']}

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age    City
# 0   John   35      NY
# 1   Anna   28  London
# 2  peter   42   Delhi

# %%
print(df.head(1))
# Out:
#    Name  Age City
#
# 0  John   35   NY

# %%
df.describe()
# Out:
#         Age
# count   3.0
# mean   35.0
# std     7.0
# min    28.0
# 25%    31.5
# 50%    35.0
# 75%    38.5
# max    42.0

# %%
df[['Name', 'Age']]
# Out:
#     Name  Age
# 0   John   35
# 1   Anna   28
# 2  peter   42

# %%
df['Occupation']= ['Engineer', 'Artist','Doctor']

# %%
df
# Out:
#     Name  Age    City Occupation
# 0   John   35      NY   Engineer
# 1   Anna   28  London     Artist
# 2  peter   42   Delhi     Doctor

# %%
filter_df = df[df['Age']>30]

# %%
filter_df
# Out:
#     Name  Age   City Occupation
# 0   John   35     NY   Engineer
# 2  peter   42  Delhi     Doctor

# %%
s_df= df.sort_values('Age')

# %%
s_df
# Out:
#     Name  Age    City Occupation
# 1   Anna   28  London     Artist
# 0   John   35      NY   Engineer
# 2  peter   42   Delhi     Doctor

# %% [markdown]
# NUMPY Block

# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5]) #to create 1D array

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr2 = np.array([[1,2,3], [4,5,6]]) # to create 2D Array

# %%
arr2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
sum_arr = np.sum(arr1)
print(sum_arr)
sum_arr
# Out:
# 15
# 15

# %%
mean_arr = np.mean(arr2, axis=0)
mean_arr
# Out:
# array([2.5, 3.5, 4.5])

# %% [markdown]
# Data Manipulation

# %%
mul_arr1 = arr1*2
mul_arr1
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
arr3 = np.array([[1,2],[3,4]])
arr4 = np.array([[5,6],[7,8]])
print(arr3)
print(arr4)
# Out:
# [[1 2]
#
#  [3 4]]
#
# [[5 6]
#
#  [7 8]]

# %%
mat_mul = np.dot(arr3,arr4)
print(mat_mul)
# Out:
# [[19 22]
#
#  [43 50]]

# %% [markdown]
# **MathplotLib Library**

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x= np.linspace(0,10,100)
print(x)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
y1 = np.sin(x)
print(y1)
# Out:
# [ 0.          0.10083842  0.20064886  0.2984138   0.39313661  0.48385164
#
#   0.56963411  0.64960951  0.72296256  0.78894546  0.84688556  0.8961922
#
#   0.93636273  0.96698762  0.98775469  0.99845223  0.99897117  0.98930624
#
#   0.96955595  0.93992165  0.90070545  0.85230712  0.79522006  0.73002623
#
#   0.65739025  0.57805259  0.49282204  0.40256749  0.30820902  0.21070855
#
#   0.11106004  0.01027934 -0.09060615 -0.19056796 -0.28858706 -0.38366419
#
#  -0.47483011 -0.56115544 -0.64176014 -0.7158225  -0.7825875  -0.84137452
#
#  -0.89158426 -0.93270486 -0.96431712 -0.98609877 -0.99782778 -0.99938456
#
#  -0.99075324 -0.97202182 -0.94338126 -0.90512352 -0.85763861 -0.80141062
#
#  -0.73701276 -0.66510151 -0.58640998 -0.50174037 -0.41195583 -0.31797166
#
#  -0.22074597 -0.12126992 -0.0205576   0.0803643   0.18046693  0.27872982
#
#   0.37415123  0.46575841  0.55261747  0.63384295  0.7086068   0.77614685
#
#   0.83577457  0.8868821   0.92894843  0.96154471  0.98433866  0.99709789
#
# ...

# %%
y2 = np.cos(x)
print(y2)
# Out:
# [ 1.          0.99490282  0.97966323  0.95443659  0.91948007  0.87515004
#
#   0.8218984   0.76026803  0.69088721  0.61446323  0.53177518  0.44366602
#
#   0.35103397  0.25482335  0.15601496  0.0556161  -0.04534973 -0.14585325
#
#  -0.24486989 -0.34139023 -0.43443032 -0.52304166 -0.60632092 -0.68341913
#
#  -0.75355031 -0.81599952 -0.87013012 -0.91539031 -0.95131866 -0.97754893
#
#  -0.9938137  -0.99994717 -0.9958868  -0.981674   -0.95745366 -0.92347268
#
#  -0.88007748 -0.82771044 -0.76690542 -0.69828229 -0.6225406  -0.54045251
#
#  -0.45285485 -0.36064061 -0.26474988 -0.16616018 -0.06587659  0.03507857
#
#   0.13567613  0.23489055  0.33171042  0.4251487   0.51425287  0.59811455
#
#   0.67587883  0.74675295  0.8100144   0.86501827  0.91120382  0.94810022
#
#   0.97533134  0.99261957  0.99978867  0.99676556  0.98358105  0.96036956
#
#   0.9273677   0.88491192  0.83343502  0.77346177  0.70560358  0.63055219
#
#   0.54907273  0.46199582  0.37020915  0.27464844  0.17628785  0.07613012
# ...

# %%
plt.figure(figsize=(4,2))
plt.plot(x,y1,label = 'sin(x)', color = 'b', linestyle = '--')
plt.plot(x,y2,label = 'cos(x)', color = 'r', linestyle = '-')
plt.title('Sin and Cosine Function Line Chart')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim(0,15)
plt.ylim(-1.5,1.5)
plt.legend()
plt.show()

# %% [markdown]
# ### **Capstone Project Section**

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/kaggle/input/capstone-day-1/used_cars_data.csv")

# %%
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
data.shape
# Out:
# (7253, 14)

# %%
data.tail()
# Out:
#       S.No.                                               Name   Location  \
# 7248   7248                  Volkswagen Vento Diesel Trendline  Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI     Mumbai
# 7250   7250                             Nissan Micra Diesel XV    Kolkata
# 7251   7251                             Volkswagen Polo GT TSI       Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats New_Price  Price
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 7253 entries, 0 to 7252
#
# Data columns (total 14 columns):
#
#  #   Column             Non-Null Count  Dtype
#
# ---  ------             --------------  -----
#
#  0   S.No.              7253 non-null   int64
#
#  1   Name               7253 non-null   object
#
#  2   Location           7253 non-null   object
#
#  3   Year               7253 non-null   int64
#
#  4   Kilometers_Driven  7253 non-null   int64
#
#  5   Fuel_Type          7253 non-null   object
#
#  6   Transmission       7253 non-null   object
#
#  7   Owner_Type         7253 non-null   object
#
#  8   Mileage            7251 non-null   object
#
#  9   Engine             7207 non-null   object
#
#  10  Power              7207 non-null   object
#
#  11  Seats              7200 non-null   float64
#
#  12  New_Price          1006 non-null   object
#
#  13  Price              6019 non-null   float64
#
# dtypes: float64(2), int64(3), object(9)
#
# ...

# %%
data.nunique()
# Out:
# S.No.                7253
# Name                 2041
# Location               11
# Year                   23
# Kilometers_Driven    3660
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               450
# Engine                150
# Power                 386
# Seats                   9
# New_Price             625
# Price                1373
# dtype: int64

# %% [markdown]
# **Counting null values**

# %%
data.isnull().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# S.No.                 0.000000
# Name                  0.000000
# Location              0.000000
# Year                  0.000000
# Kilometers_Driven     0.000000
# Fuel_Type             0.000000
# Transmission          0.000000
# Owner_Type            0.000000
# Mileage               0.027575
# Engine                0.634220
# Power                 0.634220
# Seats                 0.730732
# New_Price            86.129877
# Price                17.013650
# dtype: float64

# %%
data=data.drop(['S.No.'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 7253 entries, 0 to 7252
#
# Data columns (total 13 columns):
#
#  #   Column             Non-Null Count  Dtype
#
# ---  ------             --------------  -----
#
#  0   Name               7253 non-null   object
#
#  1   Location           7253 non-null   object
#
#  2   Year               7253 non-null   int64
#
#  3   Kilometers_Driven  7253 non-null   int64
#
#  4   Fuel_Type          7253 non-null   object
#
#  5   Transmission       7253 non-null   object
#
#  6   Owner_Type         7253 non-null   object
#
#  7   Mileage            7251 non-null   object
#
#  8   Engine             7207 non-null   object
#
#  9   Power              7207 non-null   object
#
#  10  Seats              7200 non-null   float64
#
#  11  New_Price          1006 non-null   object
#
#  12  Price              6019 non-null   float64
#
# dtypes: float64(2), int64(2), object(9)
#
# memory usage: 736.8+ KB

# %% [markdown]
# LinearRegression: Predict Price for Used Car in India

# %%
from datetime import date

# %%
date.today().year
data['Car_Age'] = date.today().year - data['Year']

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  Car_Age
# 0        NaN   1.75       13
# ...

# %%
data['Brand'] = data.Name.str.split().str.get(0)
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  Car_Age    Brand
# ...

# %%
data['Model'] = data.Name.str.split().str.get(1)+data.Name.str.split().str.get(2)

# %%
data[['Name','Brand','Model']]
# Out:
#                                                    Name          Brand  \
# 0                                Maruti Wagon R LXI CNG         Maruti
# 1                      Hyundai Creta 1.6 CRDi SX Option        Hyundai
# 2                                          Honda Jazz V          Honda
# 3                                     Maruti Ertiga VDI         Maruti
# 4                       Audi A4 New 2.0 TDI Multitronic           Audi
# ...                                                 ...            ...
# 7248                  Volkswagen Vento Diesel Trendline     Volkswagen
# 7249                             Volkswagen Polo GT TSI     Volkswagen
# 7250                             Nissan Micra Diesel XV         Nissan
# 7251                             Volkswagen Polo GT TSI     Volkswagen
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  Mercedes-Benz
#
#                  Model
# 0               WagonR
# 1             Creta1.6
# 2                JazzV
# ...

# %%
print(data.Brand.unique())
# Out:
# ['Maruti' 'Hyundai' 'Honda' 'Audi' 'Nissan' 'Toyota' 'Volkswagen' 'Tata'
#
#  'Land' 'Mitsubishi' 'Renault' 'Mercedes-Benz' 'BMW' 'Mahindra' 'Ford'
#
#  'Porsche' 'Datsun' 'Jaguar' 'Volvo' 'Chevrolet' 'Skoda' 'Mini' 'Fiat'
#
#  'Jeep' 'Smart' 'Ambassador' 'Isuzu' 'ISUZU' 'Force' 'Bentley'
#
#  'Lamborghini' 'Hindustan' 'OpelCorsa']

# %%
searchfor = ['Isuzu','ISUZU','Land','Mini']
data[data.Brand.str.contains('|'.join(searchfor))].head()
# Out:
#                                     Name    Location  Year  Kilometers_Driven  \
# 13      Land Rover Range Rover 2.2L Pure       Delhi  2014              72000
# 14        Land Rover Freelander 2 TD4 SE        Pune  2012              85000
# 176             Mini Countryman Cooper D      Jaipur  2017               8525
# 191  Land Rover Range Rover 2.2L Dynamic  Coimbatore  2018              36091
# 228            Mini Cooper Convertible S       Kochi  2017              26327
#
#     Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 13     Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 14     Diesel    Automatic     Second    0.0 kmpl  2179 CC     115 bhp    5.0
# 176    Diesel    Automatic     Second   16.6 kmpl  1998 CC     112 bhp    5.0
# 191    Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 228    Petrol    Automatic      First  16.82 kmpl  1998 CC  189.08 bhp    4.0
#
# ...

# %%
data["Brand"].replace({"ISUZU":"Isuzu", "Mini":"Mini Cooper", "Land": "Land Rover"}, inplace=True)

# %%
searchfor = ['Isuzu','ISUZU','Land','Mini']
data[data.Brand.str.contains('|'.join(searchfor))].head()
# Out:
#                                     Name    Location  Year  Kilometers_Driven  \
# 13      Land Rover Range Rover 2.2L Pure       Delhi  2014              72000
# 14        Land Rover Freelander 2 TD4 SE        Pune  2012              85000
# 176             Mini Countryman Cooper D      Jaipur  2017               8525
# 191  Land Rover Range Rover 2.2L Dynamic  Coimbatore  2018              36091
# 228            Mini Cooper Convertible S       Kochi  2017              26327
#
#     Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 13     Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 14     Diesel    Automatic     Second    0.0 kmpl  2179 CC     115 bhp    5.0
# 176    Diesel    Automatic     Second   16.6 kmpl  1998 CC     112 bhp    5.0
# 191    Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 228    Petrol    Automatic      First  16.82 kmpl  1998 CC  189.08 bhp    4.0
#
# ...

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven        Seats        Price      Car_Age
# count  7253.000000       7.253000e+03  7200.000000  6019.000000  7253.000000
# mean   2013.365366       5.869906e+04     5.279722     9.479468     9.634634
# std       3.254421       8.442772e+04     0.811660    11.187917     3.254421
# min    1996.000000       1.710000e+02     0.000000     0.440000     4.000000
# 25%    2011.000000       3.400000e+04     5.000000     3.500000     7.000000
# 50%    2014.000000       5.341600e+04     5.000000     5.640000     9.000000
# 75%    2016.000000       7.300000e+04     5.000000     9.950000    12.000000
# max    2019.000000       6.500000e+06    10.000000   160.000000    27.000000

# %%
data.describe().T
# Out:
#                     count          mean           std      min      25%  \
# Year               7253.0   2013.365366      3.254421  1996.00   2011.0
# Kilometers_Driven  7253.0  58699.063146  84427.720583   171.00  34000.0
# Seats              7200.0      5.279722      0.811660     0.00      5.0
# Price              6019.0      9.479468     11.187917     0.44      3.5
# Car_Age            7253.0      9.634634      3.254421     4.00      7.0
#
#                         50%       75%        max
# Year                2014.00   2016.00     2019.0
# Kilometers_Driven  53416.00  73000.00  6500000.0
# Seats                  5.00      5.00       10.0
# Price                  5.64      9.95      160.0
# Car_Age                9.00     12.00       27.0

# %%
data.describe(include='all').T
# Out:
#                     count unique                     top  freq          mean  \
# Name                 7253   2041  Mahindra XUV500 W8 2WD    55           NaN
# Location             7253     11                  Mumbai   949           NaN
# Year               7253.0    NaN                     NaN   NaN   2013.365366
# Kilometers_Driven  7253.0    NaN                     NaN   NaN  58699.063146
# Fuel_Type            7253      5                  Diesel  3852           NaN
# Transmission         7253      2                  Manual  5204           NaN
# Owner_Type           7253      4                   First  5952           NaN
# Mileage              7251    450               17.0 kmpl   207           NaN
# Engine               7207    150                 1197 CC   732           NaN
# Power                7207    386                  74 bhp   280           NaN
# Seats              7200.0    NaN                     NaN   NaN      5.279722
# ...

# %%
cat_cols = data.select_dtypes(include= ['object']).columns

# %%
print(cat_cols)
# Out:
# Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type',
#
#        'Mileage', 'Engine', 'Power', 'New_Price', 'Brand', 'Model'],
#
#       dtype='object')

# %%
num_cols = data.select_dtypes(include=np.number).columns.tolist()

# %%
print(num_cols)
# Out:
# ['Year', 'Kilometers_Driven', 'Seats', 'Price', 'Car_Age']

# %%
x = np.linspace(0, 2 * np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

fig, axes = plt.subplots(2, 1, figsize=(6, 4))

axes[0].plot(x, y1, label='sin(x)', color='b', linestyle='--')
axes[0].set_title('Sine Function')
axes[0].legend()

axes[1].plot(x, y2, label='cos(x)', color='r', linestyle='-')
axes[1].set_title('Cosine Function')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
for col in num_cols:
    print(col)
    print('Skew:', round(data[col].skew(),2))    
    plt.figure(figsize=(15,4))
    plt.subplot(1,2,1)
    data[col].hist(grid=False)
    plt.ylabel('count')    
    plt.subplot(1,2,2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# Year
#
# Skew: -0.84
# Kilometers_Driven
#
# Skew: 61.58
# Seats
#
# Skew: 1.9
# Price
#
# Skew: 3.34
# Car_Age
#
# Skew: 0.84

# %%
fig, axes = plt.subplots(3, 2, figsize = (18, 18))
fig.suptitle('Bar plot for all categorical variables in the dataset')
sns.countplot(ax = axes[0, 0], x = 'Fuel_Type', data = data, color = 'blue', 
              order = data['Fuel_Type'].value_counts().index);
sns.countplot(ax = axes[0, 1], x = 'Transmission', data = data, color = 'blue', 
              order = data['Transmission'].value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'Owner_Type', data = data, color = 'blue', 
              order = data['Owner_Type'].value_counts().index);
sns.countplot(ax = axes[1, 1], x = 'Location', data = data, color = 'blue', 
              order = data['Location'].value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'Brand', data = data, color = 'blue', 
              order = data['Brand'].head(20).value_counts().index);
sns.countplot(ax = axes[2, 1], x = 'Model', data = data, color = 'blue', 
              order = data['Model'].head(20).value_counts().index);
axes[1][1].tick_params(labelrotation=45);
axes[2][0].tick_params(labelrotation=90);
axes[2][1].tick_params(labelrotation=90);

# %%
dt= {'A': [1,2,3,4,5],
     'B': [2,4,6,8,10],
     'C': [3,6,9,12,15],
     'D': [20,16,12,8,4]}

df= pd.DataFrame(dt)

# %%
df
# Out:
#    A   B   C   D
# 0  1   2   3  20
# 1  2   4   6  16
# 2  3   6   9  12
# 3  4   8  12   8
# 4  5  10  15   4

# %%
sns.pairplot(df, diag_kind='kde')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(13,17))
sns.pairplot(data)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#
#   self._figure.tight_layout(*args, **kwargs)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 7253 entries, 0 to 7252
#
# Data columns (total 16 columns):
#
#  #   Column             Non-Null Count  Dtype
#
# ---  ------             --------------  -----
#
#  0   Name               7253 non-null   object
#
#  1   Location           7253 non-null   object
#
#  2   Year               7253 non-null   int64
#
#  3   Kilometers_Driven  7253 non-null   int64
#
#  4   Fuel_Type          7253 non-null   object
#
#  5   Transmission       7253 non-null   object
#
#  6   Owner_Type         7253 non-null   object
#
#  7   Mileage            7251 non-null   object
#
#  8   Engine             7207 non-null   object
#
#  9   Power              7207 non-null   object
#
#  10  Seats              7200 non-null   float64
#
#  11  New_Price          1006 non-null   object
#
#  12  Price              6019 non-null   float64
#
#  13  Car_Age            7253 non-null   int64
#
#  14  Brand              7253 non-null   object
#
# ...

# %%
fig, axarr = plt.subplots(2, 2, figsize=(10, 12))
data.groupby('Location')['Price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][0], fontsize=12)
axarr[0][0].set_title("Location Vs Price", fontsize=18)
data.groupby('Transmission')['Price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][1], fontsize=12)
axarr[0][1].set_title("Transmission Vs Price", fontsize=18)
data.groupby('Fuel_Type')['Price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][0], fontsize=12)
axarr[1][0].set_title("Fuel_Type Vs Price", fontsize=18)
data.groupby('Owner_Type')['Price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][1], fontsize=12)
axarr[1][1].set_title("Owner_Type Vs Price", fontsize=18)

plt.subplots_adjust(hspace=1.0)
plt.subplots_adjust(wspace=.5)
sns.despine()

# %%
dt = np.random.rand(10, 10)
print(dt)
sns.heatmap(dt, annot=True, cmap='YlGnBu')
plt.show()
# Out:
# [[2.91575513e-01 1.40533560e-01 1.04354773e-01 8.76609260e-01
#
#   5.65285223e-01 2.41704038e-01 3.08961778e-01 2.10881326e-01
#
#   8.40915051e-01 6.63855666e-01]
#
#  [7.90640730e-01 2.98328700e-01 3.72109927e-01 1.05130657e-02
#
#   5.95236267e-01 4.25523684e-01 8.59225478e-01 5.74317627e-01
#
#   8.60856127e-01 2.02113455e-01]
#
#  [3.10597044e-01 9.49719340e-01 7.50300879e-01 7.35347231e-01
#
#   1.94899223e-01 6.76578630e-01 1.39943421e-01 4.64768441e-01
#
#   9.55696468e-01 1.16604004e-01]
#
#  [5.97815344e-01 1.94324517e-01 4.78639293e-01 2.08510309e-01
#
#   2.71547294e-01 4.09027722e-01 6.81724711e-01 2.14660089e-01
#
#   2.06227632e-01 4.52284918e-01]
#
#  [7.75595000e-01 7.08833315e-01 4.44629198e-01 5.25613422e-01
#
#   3.51061391e-01 4.93191170e-01 1.60913937e-01 5.43225042e-01
#
#   9.70304842e-01 4.00987356e-01]
#
#  [4.34509516e-01 6.29381397e-02 1.07298442e-01 6.88150949e-01
#
#   2.52775986e-01 3.31996888e-01 4.73624874e-01 6.29663485e-01
#
# ...

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  Car_Age    Brand      Model
# ...

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(data.drop(['Kilometers_Driven','Price'],axis=1).corr(), annot = True, vmin = -1, vmax = 1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 2
#       1 plt.figure(figsize=(12, 7))
# ----> 2 sns.heatmap(data.drop(['Kilometers_Driven','Price'],axis=1).corr(), annot = True, vmin = -1, vmax = 1)
#       3 plt.show()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
data.isnull().sum()

# %%
data.loc[data["Mileage"]==0.0,'Mileage']=np.nan
data.Mileage.isnull().sum()

# %%
data.Seats.isnull().sum()
data['Seats'].fillna(value=np.nan,inplace=True)
data['Seats']=data.groupby(['Model','Brand'])['Seats'].apply(lambda x:x.fillna(x.median()))
data['Engine']=data.groupby(['Brand','Model'])['Engine'].apply(lambda x:x.fillna(x.median()))
data['Power']=data.groupby(['Brand','Model'])['Power'].apply(lambda x:x.fillna(x.median()))

# %%
data.isnull().sum()
